# %% [markdown]
# <a href="https://colab.research.google.com/github/AaryanGoswami04/SyntaxSquadHCLHackathon/blob/lakshit/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
print("Hello World")
# Out:
# Hello World
